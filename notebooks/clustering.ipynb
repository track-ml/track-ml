# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../scripts'))
from helpers import build_audio_features_data
sys.path.insert(0,'..')
import pandas as pd

# %% [markdown]
# PLAN:
#
# I am going to extract audio features for each genre, using the genres by artists.
#
# I will look at the distributions and calculate an average to see whether I can use the mean value for clustering. I will then perform some sort of clustering algorithim on these mean values for audio features to see if we can calculate some sort of similarity score for genres. This will be interesting on its own for some sort of visulisations, but more importantly we can use this for our custom loss function which will take into account the similarity between genres so as not to unfairly evaluate the models performance and hinder learning.

# %% [markdown]
# ## Step 1 - Extract Audio Features by Genre

# %%
PLAYLIST = "4rnleEAOdmFAbRcNCgZMpY"

# %%
df = build_audio_features_data([PLAYLIST])
# Out:
# 100
# 100

# %%
df[df["punk"] == 1]

data = pd.DataFrame(columns=[col for col in df.columns if not df[col].isnull().any()])
for col in df.columns:
    if df[col].isnull().any():
        data.loc[col] = df[df[col].notnull()].aggregate(func='mean')

data
# Out:
#                   acousticness  danceability    duration_ms    energy  \
# tropical house        0.099987      0.599357  214602.571429  0.827143
# europop               0.119677      0.664333  208806.333333  0.846667
# bubblegum dance       0.164000      0.645000  176453.000000  0.984000
# electro house         0.077053      0.566636  221347.272727  0.872545
# dutch trance          0.006645      0.564500  277033.500000  0.890000
# ...                        ...           ...            ...       ...
# australian indie      0.436000      0.494000  233337.000000  0.559000
# modern rock           0.258700      0.605250  228732.250000  0.592375
# italo dance           0.028155      0.596500  198560.000000  0.949000
# post-teen pop         0.120864      0.590870  225657.913043  0.785826
# finnish hip hop       0.072450      0.650900  218569.700000  0.776400
#
#                   instrumentalness       key  liveness  loudness      mode  \
# tropical house        1.292059e-01  5.500000  0.324714 -4.967000  0.357143
# europop               2.572000e-03  4.000000  0.339000 -5.729667  1.000000
# bubblegum dance       7.010000e-03  4.000000  0.164000 -7.051000  1.000000
# electro house         1.532853e-01  4.000000  0.324182 -4.407909  0.545455
# dutch trance          3.808000e-01  6.000000  0.488500 -5.241500  0.000000
# ...                            ...       ...       ...       ...       ...
# australian indie      0.000000e+00  0.000000  0.164000 -5.445000  1.000000
# modern rock           2.102375e-05  5.625000  0.189775 -6.195875  0.625000
# italo dance           3.109000e-03  0.000000  0.239000 -5.782000  0.500000
# post-teen pop         7.461383e-04  6.956522  0.174657 -4.892130  0.608696
# finnish hip hop       1.570000e-07  5.900000  0.176930 -5.116800  0.500000
#
#                   speechiness       tempo  time_signature   valence
# tropical house       0.086900  125.071714        4.000000  0.387071
# europop              0.039333  127.011333        4.000000  0.397333
# bubblegum dance      0.050800  144.954000        4.000000  0.553000
# electro house        0.100982  132.222636        4.000000  0.358455
# dutch trance         0.059150  127.985500        4.000000  0.198000
# ...                       ...         ...             ...       ...
# australian indie     0.056500  119.247000        4.000000  0.264000
# modern rock          0.076175  121.127875        3.875000  0.435937
# italo dance          0.049700  145.032500        4.000000  0.776000
# post-teen pop        0.092700  120.850391        3.826087  0.580283
# finnish hip hop      0.093050  131.795000        4.000000  0.632600
#
# [122 rows x 13 columns]
